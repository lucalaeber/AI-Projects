# %% [markdown]
# # Variable elimination in Python using pgmpy
#
# Notebook by Mika van Emmerloot (Improvements by Mats Robben)
#
# Package `pgmpy` by Ankur Ankan (currently a Post Doc at Radboud and wrote this package during his PhD)
# https://pgmpy.org/index.html

# %%
# Run this cell on Google Colab to install the pgmpy package
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.26-py3-none-any.whl.metadata (9.1 kB)
# Collecting networkx (from pgmpy)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from pgmpy) (1.26.4)
# Collecting scipy (from pgmpy)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting scikit-learn (from pgmpy)
#   Downloading scikit_learn-1.6.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: pandas in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from pgmpy) (2.2.3)
# Collecting pyparsing (from pgmpy)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting torch (from pgmpy)
#   Downloading torch-2.5.1-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting statsmodels (from pgmpy)
#   Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting tqdm (from pgmpy)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting joblib (from pgmpy)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting opt-einsum (from pgmpy)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting xgboost (from pgmpy)
#   Downloading xgboost-2.1.3-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Collecting google-generativeai (from pgmpy)
#   Downloading google_generativeai-0.8.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.10 (from google-generativeai->pgmpy)
#   Downloading google_ai_generativelanguage-0.6.10-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-api-core (from google-generativeai->pgmpy)
#   Downloading google_api_core-2.24.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai->pgmpy)
#   Downloading google_api_python_client-2.156.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai->pgmpy)
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting protobuf (from google-generativeai->pgmpy)
#   Downloading protobuf-5.29.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydantic (from google-generativeai->pgmpy)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: typing-extensions in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from google-generativeai->pgmpy) (4.12.2)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from pandas->pgmpy) (2024.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->pgmpy)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels->pgmpy)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from statsmodels->pgmpy) (24.1)
# Collecting filelock (from torch->pgmpy)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jinja2 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from torch->pgmpy) (3.1.4)
# Collecting fsspec (from torch->pgmpy)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from torch->pgmpy) (75.1.0)
# Collecting sympy==1.13.1 (from torch->pgmpy)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->pgmpy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google-generativeai->pgmpy)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from google-api-core->google-generativeai->pgmpy) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.5 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.16.0)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client->google-generativeai->pgmpy)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai->pgmpy)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai->pgmpy)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from jinja2->torch->pgmpy) (2.1.3)
# Collecting annotated-types>=0.6.0 (from pydantic->google-generativeai->pgmpy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic->google-generativeai->pgmpy)
#   Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading grpcio-1.68.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading grpcio_status-1.68.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jn/anaconda3/envs/aipt/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2024.8.30)
# Downloading pgmpy-0.1.26-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading google_generativeai-0.8.3-py3-none-any.whl (160 kB)
# Downloading google_ai_generativelanguage-0.6.10-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 1.8 MB/s eta 0:00:00-:--:--
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading scikit_learn-1.6.0-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl (29.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.9/29.9 MB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.5.1-cp312-none-macosx_11_0_arm64.whl (63.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 MB 1.5 MB/s eta 0:00:0000:0100:02
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading xgboost-2.1.3-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading google_api_core-2.24.0-py3-none-any.whl (158 kB)
# Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading protobuf-5.29.2-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading google_api_python_client-2.156.0-py2.py3-none-any.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 1.2 MB/s eta 0:00:00a 0:00:01m
# Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 871.0 kB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.1 MB/s eta 0:00:00-:--:--
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading grpcio-1.68.1-cp312-cp312-macosx_10_9_universal2.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 987.4 kB/s eta 0:00:0000:0100:01
# Downloading grpcio_status-1.68.1-py3-none-any.whl (14 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: mpmath, uritemplate, tqdm, threadpoolctl, sympy, scipy, pyparsing, pydantic-core, pyasn1, protobuf, patsy, opt-einsum, networkx, joblib, grpcio, fsspec, filelock, cachetools, annotated-types, xgboost, torch, scikit-learn, rsa, pydantic, pyasn1-modules, proto-plus, httplib2, googleapis-common-protos, statsmodels, grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai, pgmpy
# Successfully installed annotated-types-0.7.0 cachetools-5.5.0 filelock-3.16.1 fsspec-2024.10.0 google-ai-generativelanguage-0.6.10 google-api-core-2.24.0 google-api-python-client-2.156.0 google-auth-2.37.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.3 googleapis-common-protos-1.66.0 grpcio-1.68.1 grpcio-status-1.68.1 httplib2-0.22.0 joblib-1.4.2 mpmath-1.3.0 networkx-3.4.2 opt-einsum-3.4.0 patsy-1.0.1 pgmpy-0.1.26 proto-plus-1.25.0 protobuf-5.29.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.10.4 pydantic-core-2.27.2 pyparsing-3.2.0 rsa-4.9 scikit-learn-1.6.0 scipy-1.14.1 statsmodels-0.14.4 sympy-1.13.1 threadpoolctl-3.5.0 torch-2.5.1 tqdm-4.67.1 uritemplate-4.1.1 xgboost-2.1.3

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# %% [markdown]
# # BIF file reader
# If you want to do inference on a different network you can use the following code to load a .bif file and do inference. If you are looking for Bayesian Networks (.bif files) to test your implementation, have a look at this website: https://www.bnlearn.com/bnrepository/

# %%
from pgmpy.readwrite import BIFReader

reader = BIFReader("survey.bif") # Import your own Bayesian Network

# %%
model = reader.get_model()

print(model.edges)
print(model.nodes)
# Out:
# [('A', 'E'), ('S', 'E'), ('E', 'O'), ('E', 'R'), ('O', 'T'), ('R', 'T')]
# ['A', 'S', 'E', 'O', 'R', 'T']

# %%
inference = VariableElimination(model)

result =  inference.query(
          variables=['A'],
          evidence={},     # Keep in mide that variables in most .bif files are strings, so if you have True and False it should be 'True' and 'False' in your evidence dict
          elimination_order=None,
          joint=False)

for factor in result.values():
    print(factor)
# Out:
# 0it [00:00, ?it/s]
# +----------+----------+
# | A        |   phi(A) |
# +==========+==========+
# | A(young) |   0.3000 |
# +----------+----------+
# | A(adult) |   0.5000 |
# +----------+----------+
# | A(old)   |   0.2000 |
# +----------+----------+

# %% [markdown]
# If you want to dive deeper in the pgmpy package and make your own networks, you can take a look at the code below.

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# The order in which the truth values are specified follows the order you would expect to see in a truth table:
#
# | Tampering |  f   |
# |-----------|------|
# | False     | 0.98 |
# | True      | 0.02 |
#
# ---
#
# | Alarm | Tampering | Fire  |   f    |
# |-------|-----------|-------|--------|
# | False |   False   | False | 0.9999 |
# | False |   False   | True  | 0.0100 |
# | False |   True    | False | 0.1500 |
# | False |   True    | True  | 0.5000 |
# | True  |   False   | False | 0.0001 |
# | True  |   False   | True  | 0.9900 |
# | True  |   True    | False | 0.8500 |
# | True  |   True    | True  | 0.5000 |
#
# ---
#
# | Leaving | Alarm |   f   |
# |---------|-------|-------|
# | False   | False | 0.999 |
# | False   | True  | 0.120 |
# | True    | False | 0.001 |
# | True    | True  | 0.880 |
#
# CPT's tend to be given with the "True" rows first (sometimes omitting the "False" rows altogether since these can be inferred), so pay attention to this 😁.

# %%
cpd_tampering = TabularCPD(
                variable='Tampering', variable_card=2,
                values=[[.98], [0.02]])
print(cpd_tampering)

cpd_alarm = TabularCPD(
            variable='Alarm', variable_card=2,
            values=[[0.9999, 0.0100, 0.1500, 0.5],
                    [0.0001, 0.9900, 0.8500, 0.5]],
            evidence=['Tampering', 'Fire'],
            evidence_card=[2, 2])
print(cpd_alarm)

cpd_leaving = TabularCPD(
              variable='Leaving', variable_card=2,
              values=[[0.999, 0.12], [0.001, 0.88]],
              evidence=['Alarm'], evidence_card=[2])
print(cpd_leaving)
# Out:
# +--------------+------+
# | Tampering(0) | 0.98 |
# +--------------+------+
# | Tampering(1) | 0.02 |
# +--------------+------+
# +-----------+--------------+--------------+--------------+--------------+
# | Tampering | Tampering(0) | Tampering(0) | Tampering(1) | Tampering(1) |
# +-----------+--------------+--------------+--------------+--------------+
# | Fire      | Fire(0)      | Fire(1)      | Fire(0)      | Fire(1)      |
# +-----------+--------------+--------------+--------------+--------------+
# | Alarm(0)  | 0.9999       | 0.01         | 0.15         | 0.5          |
# +-----------+--------------+--------------+--------------+--------------+
# | Alarm(1)  | 0.0001       | 0.99         | 0.85         | 0.5          |
# +-----------+--------------+--------------+--------------+--------------+
# +------------+----------+----------+
# | Alarm      | Alarm(0) | Alarm(1) |
# +------------+----------+----------+
# | Leaving(0) | 0.999    | 0.12     |
# +------------+----------+----------+
# | Leaving(1) | 0.001    | 0.88     |
# +------------+----------+----------+

# %% [markdown]
# In the `TabularCPD` constructor, the `evidence` parameter is a list containing the names of the direct parents.
# The `variable_card` and `evidence_card` parameters denote the cardinality (= number of different values) of the node and its parents, respectively.
# In this notebook I only use binary variables, so the cardinality will always be 2.

# %%
example_model = BayesianNetwork([
                ('Burglary', 'Alarm'),
                ('Earthquake', 'Alarm')])

print(example_model.nodes)
print(example_model.edges)
print(example_model.get_parents('Alarm'))
# Out:
# ['Burglary', 'Alarm', 'Earthquake']
# [('Burglary', 'Alarm'), ('Earthquake', 'Alarm')]
# ['Burglary', 'Earthquake']

# %% [markdown]
# As can be seen, the `BayesianNetwork` is constructed using a list of edges, where `(A, B)` denotes an edge $A \to B$, making $A$ a parent of $B$.

# %% [markdown]
# ## Example 1: Earthquake
#
# Here we have the bayesian network with the following edges:
# - $Burglary \rightarrow Alarm$
# - $Earthquake \rightarrow Alarm$
# - $Alarm \rightarrow JohnCalls$
# - $Alarm \rightarrow MaryCalls$
#
# This network can be found at https://www.bnlearn.com/bnrepository/discrete-small.html#earthquake and is also given as a .bif file for the assignment.

# %%
earthquake_model =  BayesianNetwork([
                    ('Burglary', 'Alarm'),
                    ('Earthquake', 'Alarm'),
                    ('Alarm', 'JohnCalls'),
                    ('Alarm', 'MaryCalls')])

# Defining the parameters using CPT
cpd_burglary =  TabularCPD(
                variable='Burglary', variable_card=2,
                values=[[.999], [0.001]])

cpd_earthquake =  TabularCPD(
                  variable='Earthquake', variable_card=2,
                  values=[[0.98], [0.02]])

cpd_alarm = TabularCPD(
            variable='Alarm', variable_card=2,
            values=[[0.999, 0.71, 0.06, 0.05],
                    [0.001, 0.29, 0.94, 0.95]],
            evidence=['Burglary', 'Earthquake'],
            evidence_card=[2, 2])

cpd_johncalls = TabularCPD(
                variable='JohnCalls', variable_card=2,
                values=[[0.95, 0.1], [0.05, 0.9]],
                evidence=['Alarm'], evidence_card=[2])

cpd_marycalls = TabularCPD(
                variable='MaryCalls', variable_card=2,
                values=[[0.99, 0.3], [0.01, 0.7]],
                evidence=['Alarm'], evidence_card=[2])

# Associating the parameters with the model structure
earthquake_model.add_cpds(cpd_burglary, cpd_earthquake, cpd_alarm, cpd_johncalls, cpd_marycalls)

print(earthquake_model)
# Out:
# BayesianNetwork with 5 nodes and 4 edges

# %%
inference = VariableElimination(earthquake_model)

# Calculate the CPT for Alarm, when observing Burglary to be true
result =  inference.query(
          variables=['Alarm'],
          evidence={'Burglary': True},
          elimination_order=['MaryCalls', 'JohnCalls', 'Earthquake'],
          joint=False)

for factor in result.values():
    print(factor)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# +----------+--------------+
# | Alarm    |   phi(Alarm) |
# +==========+==============+
# | Alarm(0) |       0.0598 |
# +----------+--------------+
# | Alarm(1) |       0.9402 |
# +----------+--------------+

# %% [markdown]
# ## Example 2: Alarm
#
# Here we have the bayesian network with the following edges:
# - $Tampering \rightarrow Alarm$
# - $Fire \rightarrow Alarm$
# - $Fire \rightarrow Smoke$
# - $Alarm \rightarrow Leaving$
# - $Leaving \rightarrow Report$
#
# This network can be found as the first example on http://artint.info/2e/html/ArtInt2e.Ch8.S3.SS2.html#Ch8.Thmciexamplered15 and should be very familiar as it has been used in the slides as well.

# %%
alarm_model = BayesianNetwork([
              ('Tampering', 'Alarm'),
              ('Fire', 'Alarm'),
              ('Fire', 'Smoke'),
              ('Alarm', 'Leaving'),
              ('Leaving', 'Report')])

# Defining the parameters using CPT
cpd_tampering = TabularCPD(
                variable='Tampering', variable_card=2,
                values=[[.98], [0.02]])

cpd_fire =  TabularCPD(
            variable='Fire', variable_card=2,
            values=[[0.99], [0.01]])

cpd_alarm = TabularCPD(
            variable='Alarm', variable_card=2,
            values=[[0.9999, 0.0100, 0.1500, 0.5],
                    [0.0001, 0.9900, 0.8500, 0.5]],
            evidence=['Tampering', 'Fire'],
            evidence_card=[2, 2])

cpd_smoke = TabularCPD(
            variable='Smoke', variable_card=2,
            values=[[0.99, 0.1], [0.01, 0.9]],
            evidence=['Fire'], evidence_card=[2])

cpd_leaving = TabularCPD(
              variable='Leaving', variable_card=2,
              values=[[0.999, 0.12], [0.001, 0.88]],
              evidence=['Alarm'], evidence_card=[2])

cpd_report =  TabularCPD(
              variable='Report', variable_card=2,
              values=[[0.99, 0.25], [0.01, 0.75]],
              evidence=['Leaving'], evidence_card=[2])

# Associating the parameters with the model structure
alarm_model.add_cpds(cpd_tampering, cpd_fire, cpd_alarm, cpd_smoke, cpd_leaving, cpd_report)

print(alarm_model)
# Out:
# BayesianNetwork with 6 nodes and 5 edges

# %%
inference = VariableElimination(alarm_model)

# Calculate the CPT for Tampering, when observing Smoke to be true and Report to be true
result =  inference.query(
          variables=['Tampering'],
          evidence={'Smoke': True, 'Report':True},
          elimination_order=['Leaving', 'Fire', 'Alarm'],
          joint=False)

for factor in result.values():
    print(factor)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# +--------------+------------------+
# | Tampering    |   phi(Tampering) |
# +==============+==================+
# | Tampering(0) |           0.9716 |
# +--------------+------------------+
# | Tampering(1) |           0.0284 |
# +--------------+------------------+

# %% [markdown]
# ## Example 3: Alarm
#
# Here we have the bayesian network with the following edges:
# - $A \rightarrow C$
# - $B \rightarrow C$
# - $B \rightarrow D$
# - $C \rightarrow E$
# - $C \rightarrow F$
#
# This is the network from the knowledge clip on Brightspace.

# %%
clip_model =  BayesianNetwork([
              ('A', 'C'),
              ('B', 'C'),
              ('B', 'D'),
              ('C', 'E'),
              ('C', 'F')])

# Defining the parameters using CPT
cpd_a = TabularCPD(
        variable='A', variable_card=2,
        values=[[0.1], [0.9]])

cpd_b = TabularCPD(
        variable='B', variable_card=2,
        values=[[0.8], [0.2]])

cpd_c = TabularCPD(
        variable='C', variable_card=2,
        values=[[0.6, 0.3, 0.2, 0.9],
                [0.4, 0.7, 0.8, 0.1]],
        evidence=['A', 'B'],
        evidence_card=[2, 2])

cpd_d = TabularCPD(
        variable='D', variable_card=2,
        values=[[0.2, 0.9], [0.8, 0.1]],
        evidence=['B'], evidence_card=[2])

cpd_e = TabularCPD(
        variable='E', variable_card=2,
        values=[[0.8, 0.3], [0.2, 0.7]],
        evidence=['C'], evidence_card=[2])

cpd_f = TabularCPD(
        variable='F', variable_card=2,
        values=[[0.1, 0.8], [0.9, 0.2]],
        evidence=['C'], evidence_card=[2])

# Associating the parameters with the model structure
clip_model.add_cpds(cpd_a, cpd_b, cpd_c, cpd_d, cpd_e, cpd_f)

print(clip_model)
# Out:
# BayesianNetwork with 6 nodes and 5 edges

# %%
inference = VariableElimination(clip_model)

# Calculate the CPT for E, when not observing anything
result =  inference.query(
          variables=['E'],
          evidence=None,
          elimination_order=['D', 'F', 'A', 'B', 'C'],
          joint=False)

for factor in result.values():
    print(factor)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# +------+----------+
# | E    |   phi(E) |
# +======+==========+
# | E(0) |   0.4800 |
# +------+----------+
# | E(1) |   0.5200 |
# +------+----------+
